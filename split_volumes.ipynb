# %%
from fns import *

# %%
rootPath = "/mnt/DATA/gp1514/Dropbox/2016-paolo/preprocessed_data/"
dataPath = rootPath + "LabelMapsNEW2_1.00-1.00-1.00/"
claheDataPath = rootPath + "LabelMapsNEW2_1.00-1.00-1.00_clahe/"
trainingCases = loadCases("training.txt")
validationCases = loadCases("validation.txt")
testingCases = loadCases("testing.txt")
files = np.concatenate([[dataPath + name + '/case.nrrd' for name in trainingCases], 
                [dataPath + name + '/case.nrrd' for name in validationCases], 
                [dataPath + name + '/case.nrrd' for name in testingCases]])
files_labels = np.concatenate([[dataPath + name + '/needles.nrrd' for name in trainingCases], 
                [dataPath + name + '/needles.nrrd' for name in validationCases], 
                [dataPath + name + '/needles.nrrd' for name in testingCases]])

# %%
for file in files:
    data, options = nrrd.read(file)
    data = data.astype(np.float32)
    arr_data = cutVolume(data)
    for i, img in enumerate(arr_data):
        name = file.replace('.nrrd', '')
        name += '_%d.nrrd'%i
        nrrd.write(name, img)
# Out:
# Original input shape (200, 160, 192)
# Padded input shape: (288, 248, 280)
# # of parts 5 5 5
# number of tiles: 18
# Original input shape (200, 200, 78)
# Padded input shape: (288, 288, 166)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (200, 200, 89)
# Padded input shape: (288, 288, 177)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (280, 224, 66)
# Padded input shape: (368, 312, 154)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (280, 224, 84)
# Padded input shape: (368, 312, 172)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (200, 200, 77)
# Padded input shape: (288, 288, 165)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (220, 220, 240)
# Padded input shape: (308, 308, 328)
# # of parts 6 6 6
# number of tiles: 36
# Original input shape (200, 200, 240)
# Padded input shape: (288, 288, 328)
# # of parts 5 5 6
# number of tiles: 36
# Original input shape (200, 200, 78)
# Padded input shape: (288, 288, 166)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (200, 200, 108)
# Padded input shape: (288, 288, 196)
# # of parts 5 5 4
# number of tiles: 9
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 255)
# Padded input shape: (388, 283, 343)
# # of parts 7 7 6
# number of tiles: 60
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (280, 224, 66)
# Padded input shape: (368, 312, 154)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (319, 319, 128)
# Padded input shape: (407, 407, 216)
# # of parts 7 7 4
# number of tiles: 50
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (239, 239, 160)
# Padded input shape: (327, 327, 248)
# # of parts 6 6 5
# number of tiles: 18
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (280, 224, 84)
# Padded input shape: (368, 312, 172)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 204)
# Padded input shape: (388, 283, 292)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (299, 194, 211)
# Padded input shape: (387, 282, 299)
# # of parts 7 7 5
# number of tiles: 36
# Original input shape (300, 195, 191)
# Padded input shape: (388, 283, 279)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 204)
# Padded input shape: (388, 283, 292)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 166)
# Padded input shape: (388, 283, 254)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (300, 195, 191)
# Padded input shape: (388, 283, 279)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (319, 319, 220)
# Padded input shape: (407, 407, 308)
# # of parts 7 7 6
# number of tiles: 75

# %%
for file in files_labels:
    file = file.replace('_clahe', '')
    data, options = nrrd.read(file)
    data = data.astype(np.uint8)
    arr_data = cutVolume(data)
    for i, img in enumerate(arr_data):
        name = file.replace('.nrrd', '')
        name += '_%d.nrrd'%i
        nrrd.write(name, img)
# Out:
# Original input shape (200, 160, 192)
# Padded input shape: (288, 248, 280)
# # of parts 5 5 5
# number of tiles: 18
# Original input shape (200, 200, 78)
# Padded input shape: (288, 288, 166)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (200, 200, 89)
# Padded input shape: (288, 288, 177)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (280, 224, 66)
# Padded input shape: (368, 312, 154)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (280, 224, 84)
# Padded input shape: (368, 312, 172)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (200, 200, 77)
# Padded input shape: (288, 288, 165)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (220, 220, 240)
# Padded input shape: (308, 308, 328)
# # of parts 6 6 6
# number of tiles: 36
# Original input shape (200, 200, 240)
# Padded input shape: (288, 288, 328)
# # of parts 5 5 6
# number of tiles: 36
# Original input shape (200, 200, 78)
# Padded input shape: (288, 288, 166)
# # of parts 5 5 3
# number of tiles: 9
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (200, 200, 108)
# Padded input shape: (288, 288, 196)
# # of parts 5 5 4
# number of tiles: 9
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 255)
# Padded input shape: (388, 283, 343)
# # of parts 7 7 6
# number of tiles: 60
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (280, 224, 66)
# Padded input shape: (368, 312, 154)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (319, 319, 128)
# Padded input shape: (407, 407, 216)
# # of parts 7 7 4
# number of tiles: 50
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (239, 239, 160)
# Padded input shape: (327, 327, 248)
# # of parts 6 6 5
# number of tiles: 18
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (280, 224, 84)
# Padded input shape: (368, 312, 172)
# # of parts 7 7 3
# number of tiles: 12
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 204)
# Padded input shape: (388, 283, 292)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (299, 194, 211)
# Padded input shape: (387, 282, 299)
# # of parts 7 7 5
# number of tiles: 36
# Original input shape (300, 195, 191)
# Padded input shape: (388, 283, 279)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 153)
# Padded input shape: (388, 283, 241)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 230)
# Padded input shape: (388, 283, 318)
# # of parts 7 7 6
# number of tiles: 45
# Original input shape (300, 195, 192)
# Padded input shape: (388, 283, 280)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 204)
# Padded input shape: (388, 283, 292)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 179)
# Padded input shape: (388, 283, 267)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (300, 195, 166)
# Padded input shape: (388, 283, 254)
# # of parts 7 7 5
# number of tiles: 30
# Original input shape (220, 220, 204)
# Padded input shape: (308, 308, 292)
# # of parts 6 6 5
# number of tiles: 27
# Original input shape (300, 195, 191)
# Padded input shape: (388, 283, 279)
# # of parts 7 7 5
# number of tiles: 45
# Original input shape (319, 319, 220)
# Padded input shape: (407, 407, 308)
# # of parts 7 7 6
# number of tiles: 75
