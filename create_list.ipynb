# %%
from fns import *
import glob

# %%
rootPath = "/home/gp1514/DATA/"
dataPath = rootPath + "LabelMapsNEW2_1.00-1.00-1.00/"
claheDataPath = rootPath + "LabelMapsNEW2_1.00-1.00-1.00/"
trainingCases = loadCases("training.txt")
validationCases = loadCases("validation.txt")
testingCases = loadCases("testing.txt")

files_training = [claheDataPath + name + '/case.nrrd' for name in trainingCases]
files_validation = [claheDataPath + name + '/case.nrrd' for name in validationCases]
files_testing = [claheDataPath + name + '/case.nrrd' for name in testingCases]

# %%
inputs = [files_training, 
          files_validation, 
          files_testing]

outputs = ['training_subvolumes.txt', 'validation_subvolumes.txt', 'testing_subvolumes.txt']

for i in range(3):
    files = []

    for file in inputs[i]: 
        folder = file.replace('case.nrrd', '')
        files.append(glob.glob(folder+'case_*.nrrd'))

    files = np.concatenate(files)
    with open(outputs[i], 'w') as f:
        for file in files:
            
            f.write(file + '\n')

# %%
inputs[2]
# Out:
# ['/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/028/case.nrrd',
#  '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/051/case.nrrd',
#  '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/054/case.nrrd']

# %%
with open('training_subvolumes.txt', 'r') as f:
    training_cases = f.read().splitlines()

print(training_cases)
# Out:
# ['/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_13.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_2.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_11.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_4.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_1.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_12.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_9.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_7.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_10.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_5.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_0.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_8.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_14.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_15.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_3.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_6.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_17.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/007/case_16.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_2.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_4.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_1.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_7.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_5.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_0.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_8.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_3.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/008/case_6.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_2.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_4.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_1.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_7.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_5.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_0.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_8.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_3.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/012/case_6.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_2.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_11.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_4.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_1.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_9.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_7.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_10.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_5.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_0.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_8.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_3.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/014/case_6.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_2.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_11.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_4.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_1.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_9.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_7.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_10.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_5.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_0.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_8.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_3.nrrd', '/home/gp1514/DATA/LabelMapsNEW2_1.00-1.00-1.00/016/case_6.nrrd', '/home/gp1514/DATA/LabelMap ...

# %%
# ?f.readlines
